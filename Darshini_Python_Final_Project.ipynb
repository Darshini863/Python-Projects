# %%
# Import all the neccessary library
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
import numpy as np
import matplotlib as mat
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")
import statistics as st

# %% [markdown]
# # TASK 1

# %% [markdown]
# Load the movie dataset in the Python notebook. Display the numbers of rows and columns in the dataset. Display the titles and genres of the first 50 movies from the dataset.

# %%
# Load the movie dataset into the python notebook
df = pd.read_csv("DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv")
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# displaying the number of rows and the column
print("The shape the dataset is ", df.shape)
# Out:
# The shape the dataset is  (4803, 20)

# %% [markdown]
# The dataset contains 4803 rows and 20 columns.

# %%
# display the title and genre for first 50 movies
df.loc[:50, ['genres','original_title']]
# Out:
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# ...

# %% [markdown]
# These are the title and genres of first 50 movies in the data set.

# %% [markdown]
# # TASK 2

# %% [markdown]
#  Identify the columns that have null values and perform the null value treatment. Choose the imputation method based on the type of data in the columns of interest.

# %%
# identify the null values in the data frame
df.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# The dataset cantains the null values in the homepage, overview, release_date, runtime and tagline this contains the null values.
# amongh them homepage, overview,release_date and tagline columns are categorical column , whereas runtime column is numerical.

# %%
# seperating the categorical and continous columns
a = df.select_dtypes(exclude = 'object')
b = df.select_dtypes(include = 'object')
alist = list(a.columns)
blist = list(b.columns)
print(tabulate({"Categorical":blist,
                "continuous": alist}, headers = ["categorical", "continuous"]))
# Out:
# categorical           continuous
# --------------------  ------------
# genres                budget
# homepage              id
# keywords              popularity
# original_language     revenue
# original_title        runtime
# overview              vote_average
# production_companies  vote_count
# production_countries
# release_date
# spoken_languages
# status
# tagline
# title

# %%
# Imputing the values
df['homepage'] = df['homepage'].fillna('http://www.missionimpossible.com/')

# %%
df['overview'] = df['overview'].fillna(df['overview'].mode())

# %%
df['release_date'] = df['release_date'].fillna('01-01-2006')

# %%
df['tagline'] = df['tagline'].fillna('Based on a true story')

# %%
df['runtime'] = df['runtime'].fillna(df['runtime'].mean())

# %%
df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # TASK 3

# %% [markdown]
# Display the movie categories that have a budget greater than $220,000

# %%
# Display the movie category having the budget greater than 220000
df_budget = df[df.budget > 220000]

# %%
import json
df_combined = pd.concat([df_budget["genres"].apply(lambda x: [genre["name"] for genre in json.loads(x)]), df_budget["budget"]], axis=1)
df_combined.columns = ["genres", "budget"]
# import json
# df_combined = pd.concat([df_budget["genres"].apply(lambda x: [genre["name"] for genre in json.loads(json.dumps(x))]), df_budget["budget"]], axis=1)
# df_combined.columns = ["genres", "budget"]

# %%
df_combined
# Out:
#                                              genres     budget
# 0     [Action, Adventure, Fantasy, Science Fiction]  237000000
# 1                      [Adventure, Fantasy, Action]  300000000
# 2                        [Action, Adventure, Crime]  245000000
# 3                  [Action, Crime, Drama, Thriller]  250000000
# 4              [Action, Adventure, Science Fiction]  260000000
# ...                                             ...        ...
# 4680                      [Crime, Horror, Thriller]     450000
# 4682                                       [Horror]   13000000
# 4720                                        [Drama]    8500000
# 4758                    [Thriller, Science Fiction]    4000000
# 4770                                [Drama, Comedy]     500000
#
# [3684 rows x 2 columns]

# %% [markdown]
# There are  3684 movies having there budget less than the 220000 amongh them  242 movies belongs to the Drama category , followed by 216 movies belongs to the comedy category.

# %%
df_combined['genres'].value_counts()
# Out:
# [Drama]                                                 242
# [Comedy]                                                216
# [Drama, Romance]                                        116
# [Comedy, Romance]                                       104
# [Comedy, Drama]                                          95
#                                                        ...
# [Drama, Thriller, Mystery, War]                           1
# [Comedy, Crime, Action]                                   1
# [Action, Science Fiction, Adventure, Comedy, Family]      1
# [Comedy, Family, Music]                                   1
# [Foreign, Documentary]                                    1
# Name: genres, Length: 1009, dtype: int64

# %% [markdown]
# # TASK 4

# %% [markdown]
# Display the movie categories where the revenue is greater than $961,000,000.

# %%
# display the movie category where revenue greater than 961000000
df_revenue = df[df.revenue > 961000000]

# %%
# df_combined = pd.concat([df_revenue["genres"].apply(lambda x: [genre["name"] for genre in json.loads(x)], df_revenue["revenue"]], axis=1)
# df_combined.columns = ["genres", "revenue"]
df_combined= pd.concat([df_revenue["genres"].apply(lambda x: [genre["name"] for genre in json.loads(x)]), df_revenue["revenue"]], axis=1)
df_combined.columns = ["genres", "revenue"]
# df_combined = pd.concat([df_revenue["genres"].apply(lambda x: [genre["name"] for genre in x]), df_revenue["revenue"]], axis=1)
# df_combined.columns = ["genres", "revenue"]

# %%
df_combined
# Out:
#                                              genres     revenue
# 0     [Action, Adventure, Fantasy, Science Fiction]  2787965087
# 3                  [Action, Crime, Drama, Thriller]  1084939099
# 7              [Action, Adventure, Science Fiction]  1405403694
# 12                     [Adventure, Fantasy, Action]  1065659812
# 16             [Science Fiction, Action, Adventure]  1519557910
# 17                     [Adventure, Action, Fantasy]  1045713802
# 25                       [Drama, Romance, Thriller]  1845034188
# 26             [Adventure, Action, Science Fiction]  1153304495
# 28   [Action, Adventure, Science Fiction, Thriller]  1513528810
# 29                    [Action, Adventure, Thriller]  1108561013
# 31             [Action, Adventure, Science Fiction]  1215439994
# 32                     [Family, Fantasy, Adventure]  1025491110
# 36             [Science Fiction, Action, Adventure]  1091405097
# 42                      [Animation, Family, Comedy]  1066969703
# ...

# %%
len(df_combined)
# Out:
# 24

# %%
df_combined['genres'].value_counts()
# Out:
# [Adventure, Fantasy, Action]                      3
# [Action, Adventure, Science Fiction]              2
# [Science Fiction, Action, Adventure]              2
# [Action, Adventure, Fantasy, Science Fiction]     1
# [Action]                                          1
# [Animation, Comedy, Family]                       1
# [Adventure, Fantasy, Family]                      1
# [Animation, Adventure, Family]                    1
# [Family, Adventure, Drama, Fantasy]               1
# [Drama, Action, Crime, Thriller]                  1
# [Action, Science Fiction, Adventure]              1
# [Family, Fantasy, Adventure]                      1
# [Animation, Family, Comedy]                       1
# [Action, Crime, Drama, Thriller]                  1
# [Action, Adventure, Thriller]                     1
# [Action, Adventure, Science Fiction, Thriller]    1
# [Adventure, Action, Science Fiction]              1
# [Drama, Romance, Thriller]                        1
# ...

# %% [markdown]
# # There are only 24 movies having there revenue greater then 961000000, amongh then 3 movies belongs to [Adventure, Fantasy, Action] genre and   4 of them belongs to the [action, adventure, Science fiction] genre .

# %% [markdown]
# # TASK 5

# %% [markdown]
#  In the dataset, there are some movies for which the budget and revenue columns have the value 0, which mean unknown values. Remove the rows with value 0 from both the budget and revenue columns.

# %%
df.loc[(df["budget"] == 0) & (df["revenue"] == 0)]
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
# Remove the rows having budget and revenue 0 
df = df.loc[(df["budget"] != 0) & (df["revenue"] != 0)]

# %%
df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Out of 4803 movies nearly 890 movies are having the budget and revenue has zero.So here we are only considering the rows which are having non zero budget and the revenue.

# %% [markdown]
# # TASK 6

# %% [markdown]
#  List the top 10 movies with the highest revenues

# %%
# Top 10 movies with highest revenue and top10 movies with least budget
df_sort = df.sort_values(['revenue'], ascending = [False]).head(10)
df_sort
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44   190000000                     [{"id": 28, "name": "Action"}]
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 124  150000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 546   74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# 25                         http://www.titanicmovie.com     597
# ...

# %%
df_sort = df.sort_values(['budget'], ascending = [True]).head(10)
df_sort
# Out:
#       budget                                             genres  \
# 4238       1  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3611       4  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3372       7  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 3419       7  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4608       8  [{"id": 14, "name": "Fantasy"}, {"id": 27, "na...
# 3131      10  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3137      10  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 2933      11  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 1912      25                      [{"id": 18, "name": "Drama"}]
# 1771      28  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
#
#                                homepage      id  \
# 4238  http://www.missionimpossible.com/    3082
# 3611  http://www.missionimpossible.com/   22649
# 3372  http://www.missionimpossible.com/   13006
# 3419  http://www.missionimpossible.com/   38415
# ...

# %% [markdown]
# # The movie titled as "Avatar" is having the highest revenue is about 2787965087 and the least budget is about 237000000, followe dby the Titanic movie having there revenue 1845034188 and the budget 200000000 .

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
# # TASK 7

# %% [markdown]
#  How are popularities of movies related with the movie budgets? Are they correlated or totally uncorrelated with each other? Write the interpretation of your analysis.

# %%
# Popularity of the movies related to the movie budget
corr = df['popularity'].corr(df['budget'])
corr
# Out:
# 0.4319901360079756

# %%
plt.scatter( df['popularity'],df['budget'],color='yellow',label= "R=" +str(corr))
# plt.xlabel("R=" +str(mc_corr1))
# plt.xlim(5,35)
# plt.ylim(3.5,10)
plt.legend()
plt.show()

# %%
sns.regplot(data = df,x="popularity",y="budget" )
plt.show()

# %% [markdown]
# # Popularity and Budget has positive correlation but that is not a strong correlation.

# %% [markdown]
# # Task 8

# %% [markdown]
#  Identify and display the names of all production companies along with the number of times.

# %%
# Production company along with the number of time it appears
production_company = df["production_companies"].explode().value_counts(sort = True)
production_company
# Out:
# [{"name": "Paramount Pictures", "id": 4}]                                                                                                                                                             48
# []                                                                                                                                                                                                    41
# [{"name": "Universal Pictures", "id": 33}]                                                                                                                                                            35
# [{"name": "New Line Cinema", "id": 12}]                                                                                                                                                               29
# ...

# %%
# production_counts = df["production_companies"].apply(lambda x: [company["name"] for company in x]).explode().value_counts()
import ast

# Convert string representations of dictionaries to actual dictionaries
df["production_companies"] = df["production_companies"].apply(ast.literal_eval)

# Extract production company names and count occurrences
production_counts = df["production_companies"].apply(lambda x: [company["name"] for company in x]).explode().value_counts()

# %%
production_counts
# Out:
# Warner Bros.                              280
# Universal Pictures                        273
# Paramount Pictures                        245
# Twentieth Century Fox Film Corporation    201
# Columbia Pictures                         167
#                                          ...
# HW Two                                      1
# Unfinished Films                            1
# Infinity Features Entertainment             1
# British Columbia Film                       1
# Daiei Studios                               1
# Name: production_companies, Length: 3564, dtype: int64

# %%
production_company.explode().value_counts(sort = True)
# Out:
# 1     2475
# 2       86
# 3       31
# 4       10
# 5        6
# 6        3
# 7        3
# 24       2
# 13       2
# 8        2
# 9        2
# 10       1
# 48       1
# 41       1
# 12       1
# 15       1
# 18       1
# 25       1
# 28       1
# 29       1
# 35       1
# 11       1
# Name: production_companies, dtype: int64

# %%
df["production_companies"].explode()
# Out:
# 0          {'name': 'Ingenious Film Partners', 'id': 289}
# 0       {'name': 'Twentieth Century Fox Film Corporati...
# 0               {'name': 'Dune Entertainment', 'id': 444}
# 0         {'name': 'Lightstorm Entertainment', 'id': 574}
# 1               {'name': 'Walt Disney Pictures', 'id': 2}
#                               ...
# 4773      {'name': 'View Askew Productions', 'id': 16934}
# 4788         {'name': 'Dreamland Productions', 'id': 407}
# 4792                 {'name': 'Daiei Studios', 'id': 881}
# 4796                     {'name': 'Thinkfilm', 'id': 446}
# 4798               {'name': 'Columbia Pictures', 'id': 5}
# Name: production_companies, Length: 10373, dtype: object

# %%
# 3564

# %%
df_companies = df['production_companies'].str.split('|').explode().reset_index(drop=True)
df_companies
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3224   NaN
# 3225   NaN
# 3226   NaN
# 3227   NaN
# 3228   NaN
# Name: production_companies, Length: 3229, dtype: float64

# %%
count_companies = df_companies.value_counts()
count_companies
# Out:
# Series([], Name: production_companies, dtype: int64)

# %%
production_company.value_counts()
# Out:
# 1     2475
# 2       86
# 3       31
# 4       10
# 5        6
# 6        3
# 7        3
# 24       2
# 13       2
# 8        2
# 9        2
# 10       1
# 48       1
# 41       1
# 12       1
# 15       1
# 18       1
# 25       1
# 28       1
# 29       1
# 35       1
# 11       1
# Name: production_companies, dtype: int64

# %% [markdown]
# # The production company "Paramount Pictures" has appeared 48 times in our dataset

# %% [markdown]
# # TASK 9

# %% [markdown]
# Display the names of the top 25 production companies based on the number of movies they have produced in descending order of the number of movies produced.

# %%
# Top 25 production companies based on the number of movies they have produced in descending order.
production_company.sort_values(ascending = False).head(25)
# Out:
# [{"name": "Paramount Pictures", "id": 4}]                                                                           48
# []                                                                                                                  41
# [{"name": "Universal Pictures", "id": 33}]                                                                          35
# [{"name": "New Line Cinema", "id": 12}]                                                                             29
# [{"name": "Columbia Pictures", "id": 5}]                                                                            28
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                     25
# [{"name": "Warner Bros.", "id": 6194}]                                                                              24
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}]                                                                 24
# ...

# %% [markdown]
# Amongh them Paramount pictures has produced 48 movies, followed by

# %%
production_counts.head(25)
# Out:
# Warner Bros.                              280
# Universal Pictures                        273
# Paramount Pictures                        245
# Twentieth Century Fox Film Corporation    201
# Columbia Pictures                         167
# New Line Cinema                           142
# Relativity Media                          100
# Walt Disney Pictures                       96
# Touchstone Pictures                        93
# Metro-Goldwyn-Mayer (MGM)                  92
# Columbia Pictures Corporation              86
# Village Roadshow Pictures                  73
# Miramax Films                              67
# DreamWorks SKG                             67
# United Artists                             64
# Regency Enterprises                        59
# Dune Entertainment                         54
# TriStar Pictures                           50
# Lionsgate                                  49
# Canal+                                     48
# ...

# %%
production_company.head(25)
# Out:
# [{"name": "Paramount Pictures", "id": 4}]                                                                           48
# []                                                                                                                  41
# [{"name": "Universal Pictures", "id": 33}]                                                                          35
# [{"name": "New Line Cinema", "id": 12}]                                                                             29
# [{"name": "Columbia Pictures", "id": 5}]                                                                            28
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                     25
# [{"name": "Warner Bros.", "id": 6194}]                                                                              24
# [{"name": "Metro-Goldwyn-Mayer (MGM)", "id": 8411}]                                                                 24
# ...

# %% [markdown]
# # TASK 10

# %% [markdown]
#  Sort the data in descending order based on revenue and filter the top 500 movies. Find the measures of central tendency for the following columns using the filtered data:
# 1. Budget  2. revenue 3. runtime
# Perform outlier analysis for the above three columns using box plots.

# %%
df_filter = df.sort_values(['revenue'], ascending = False).head(500)
df_filter
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 397    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1744   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 698    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 717    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 714    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %%
df_central = df_filter.loc[:,['budget',"revenue","runtime"]]
df_central
# Out:
#          budget     revenue  runtime
# 0     237000000  2787965087    162.0
# 25    200000000  1845034188    194.0
# 16    220000000  1519557910    143.0
# 28    150000000  1513528810    124.0
# 44    190000000  1506249360    137.0
# ...         ...         ...      ...
# 397    85000000   219103655    121.0
# 1744   30000000   219076518    129.0
# 698    70000000   218613188     99.0
# 717    60000000   218340595    130.0
# 714    65000000   217764291    120.0
#
# [500 rows x 3 columns]

# %%
import statistics as st

Mean = []
Median = []
Mode = []

for col in df_central:
    Mean.append(df_central[col].mean())
    Median.append(df_central[col].median())
    Mode.append(st.mode(df_central[col]))
    
row_heads = ["mean", "Median", "Mode"]
col_name = ["Budget", "Revenue", "Runtime"]

d_data = pd.DataFrame([Mean, Median, Mode], columns = col_name)
d_data
# Out:
#         Budget       Revenue  Runtime
# 0  103193736.0  4.585776e+08   118.72
# 1   95000000.0  3.630016e+08   116.00
# 2  150000000.0  2.787965e+09   115.00

# %%
d_data.insert(0,"measures",row_heads)
d_data
# Out:
#   measures       Budget       Revenue  Runtime
# 0     mean  103193736.0  4.585776e+08   118.72
# 1   Median   95000000.0  3.630016e+08   116.00
# 2     Mode  150000000.0  2.787965e+09   115.00

# %%
fig,ax=plt.subplots(1,3,figsize=(15,7))
sns.boxplot(y=df_central['budget'],ax=ax[0],color='g')
sns.boxplot(y=df_central['revenue'],ax=ax[1],color='r')
sns.boxplot(y=df_central['runtime'],ax=ax[2],color='b')
plt.show()

# %%
df_central
# Out:
#          budget     revenue  runtime
# 0     237000000  2787965087    162.0
# 25    200000000  1845034188    194.0
# 16    220000000  1519557910    143.0
# 28    150000000  1513528810    124.0
# 44    190000000  1506249360    137.0
# ...         ...         ...      ...
# 397    85000000   219103655    121.0
# 1744   30000000   219076518    129.0
# 698    70000000   218613188     99.0
# 717    60000000   218340595    130.0
# 714    65000000   217764291    120.0
#
# [500 rows x 3 columns]

# %%
# outlier analysis for Budget
mean = int(df_central.budget.mean())
mean
x = df_central[df_central['budget'] > 280000000].index
x
# Out:
# Int64Index([17, 1], dtype='int64')

# %%
for index in x:
    df_central.loc[index, 'budget'] = mean

# %%
# outlier analysis for Revenue
mean = int(df_central.revenue.mean())
mean
x = df_central[df_central['revenue'] > mean].index
x
# Out:
# Int64Index([   0,   25,   16,   28,   44,    7,  124,   31,  546,   26,
#             ...
#               89, 2809,  244,  744,   47,  634, 2668,  566,   33, 1356],
#            dtype='int64', length=172)

# %%
for index in x:
    df_central.loc[index, 'revenue'] = mean

# %%
# outlier Analysis for Runtime
mean = int(df_central.runtime.mean())
mean
x = df_central[df_central['runtime'] > 178].index
x
# Out:
# Int64Index([25, 329, 330, 24, 110, 2278, 3813, 298, 1818, 690], dtype='int64')

# %%
for index in x:
    df_central.loc[index, 'runtime'] = mean

# %%
fig,ax=plt.subplots(1,3,figsize=(15,7))
sns.boxplot(y=df_central['budget'],ax = ax[0], color='g')
sns.boxplot(y = df_central['revenue'], ax = ax[1], color = 'y')
sns.boxplot(y = df_central['runtime'], ax = ax[2], color = 'b')
# Out:
# <AxesSubplot:ylabel='runtime'>

# %% [markdown]
# # TASK 11

# %% [markdown]
# Identify and display the names of the movies along with their run times for those movies that have above average runtime, using the data from the previous task

# %%
# display the name of the movies having runtime greater than the average
df_run = df[df.runtime > 118.72]
df_run
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4511     500000                      [{"id": 18, "name": "Drama"}]
# 4535    2000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 4592     385907                      [{"id": 18, "name": "Drama"}]
# 4661     245000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4720    8500000                      [{"id": 18, "name": "Drama"}]
#
#                                               homepage      id  \
# 0                          http://www.avatarmovie.com/   19995
# ...

# %%
df_run.loc[:,["title","runtime"]]
# Out:
#                                          title  runtime
# 0                                       Avatar    162.0
# 1     Pirates of the Caribbean: At World's End    169.0
# 2                                      Spectre    148.0
# 3                        The Dark Knight Rises    165.0
# 4                                  John Carter    132.0
# ...                                        ...      ...
# 4511                                 Fireproof    122.0
# 4535                             Seven Samurai    207.0
# 4592                               Intolerance    197.0
# 4661                            The Big Parade    151.0
# 4720                     The Birth of a Nation    120.0
#
# [940 rows x 2 columns]

# %% [markdown]
# There are totally 940 movies out of 3913 movies having there runtime greater than averagre, The movie Avatar was  having the runtime greater than average.

# %%
# extra analysis
# Relation between the budget and revenue
df['budget']
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4773        27000
# 4788        12000
# 4792        20000
# 4796         7000
# 4798       220000
# Name: budget, Length: 3229, dtype: int64

# %%
# plt.scatter( df['budget'],df['revenue'],color='blue')
sns.regplot(data = df,x="revenue",y="budget" )
plt.show()

# %%
df['budget'].corr(df['revenue'])
# Out:
# 0.7053993306781392

# %%
df['popularity'].corr(df['budget'])
# Out:
# 0.4319901360079756

# %%
df['popularity'].corr(df['revenue'])
# Out:
# 0.6022455015824714

# %%
df['budget'].corr(df['vote_count'])
# Out:
# 0.5401653840390924

# %%
df['revenue'].corr(df['vote_count'])
# Out:
# 0.7562103519586976

# %%
df['popularity'].corr(df['vote_count'])
# Out:
# 0.7490877349241364

# %%
sns.regplot(data = df,x="budget",y="vote_count" )
plt.show()

# %%
df['popularity'].corr(df['revenue'])
# Out:
# 0.6022455015824714

# %%
df[(df['title'] == 'Avatar')]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{'name': 'Ingenious Film Partners', 'id': 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   10-12-2009  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
df['vote_count'].mean()
# Out:
# 977.2873954784764

# %%
df['vote_count'].max()
# Out:
# 13752

# %%
df['vote_count'].min()
# Out:
# 0

# %%
df['runtime'].mean()
# Out:
# 110.72437287085785

# %%
df['runtime'].max()
# Out:
# 338.0

# %%
df['popularity'].mean()
# Out:
# 29.03368851749772

# %% [markdown]
# Conclusion :
#
# The most  profitable genres are Action, Adventure, Fantasy and Science Fiction and the most popular genres are Drama, Comedy.
#
# The budget and the revenue are strongly correlated, more than 60% of the movies are belongs to the budget range between 67000000 to 207000000 and they are creating the revenue of 270000000 to 480000000.
#
# Budget and vote count were also having the strong positive correlation, high budget  movies are having the more number of vote count.
#
# Popularity and Budget were also having the positive correlation(0.545), also popularity and the revenue were also having the strong positive correlation(0.758) , popularity also depends on the vote count(0.74).
#
# The most popular production house is Warner bros has produced around 319 movies  followed by universal pictures has produced 311 movies.
